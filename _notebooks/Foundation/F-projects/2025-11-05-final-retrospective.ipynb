# %%
---
title: Final Retrospective Blog
comments: false
layout: post
permalink: /finalblog
author: Kailyn Sanford
---

# %% [markdown]
# # Final Retrospective Blog
# Over the past 12 weeks I've learned more about coding and the process of Computer Science than I could ever imagine.

# %% [markdown]
# ## Beginning of the Year to Now
#
# At the beginning of the year...
# ![evaluation](images/final/evaluation.png)
#
# #### Area I think I improved:
# * **Work Habits**: I'm better at working during class now! I used to only be able to focus at home but I feel like I can definitely get a lot more done during class.
# * **Timeliness**: I feel a lot more confident in getting things done on time, and I think everything I got done on time!
# * **Tech, Cyber Sense and Cyber Talk**: I feel like not only am I better able to follow what goes on in more and more complex code, but I also have an expanded vocabulary when it comes to talking about these topics. With the expanded vocabulary, I feel like it's easier to understand new stuff as well, because I have the words needed to associate things.
# * **Organization**: I feel like I got way better at keeping myself organized and organizing others as well. I even helped out at the beginning of projects trying to divide up work and organize who was doing what.
#
# #### Areas I can Improve on Next Tri:
# * **Work Habits and Timeliness**: These areas can always be improved, and I am in no way perfect. There are still times when I'm not 100% productive. There are also still times when I leave things for the last minute. In the future, I would like to try my best to work as hard as I can when assignments are assigned, trying my best to make the most of worktime given in class.
# * **Tech, Cyber Sense and Cyber Talk**: Obviously, this is pretty much the main part of class! I by no means know everything about computer science, so I'm always willing to improve and learn more about technology and how I can expand my vocabulary when talking about it.

# %% [markdown]
# ## 3 Sprints: Key Ideas
# Over this trimester, we've gone through three seperate sprints with 3 distinct ideas, that flow well into eachother.
# #### Sprint 1:
# * focused mostly on getting set-up, which would help us greatly later when needing to use these tools.
# * setting up virtual environment would be helpful later, especially during sprint 2 when doing python lessons and homework.
# * A highlight of this sprint for me was our gamified on-boarding lesson. This helped reinforce the ideas I was learning and helped cement them to me as I taught them to others.
# #### Sprint 2:
# * Helped develop the basic skills of compsci in lesson and homework format.
# * Found this super technical learning-focused sprint to be helpful in advance to sprint 3, where we applied a lot of these concepts.
# * A highlight of this sprint was teaching the lessons, when teaching I felt like I could really understand everything I explained, and it even helped me learn things when others asked me questions and we had to work it out together.
# #### Sprint 3:
# * real-world applications of fundamentals we learned from sprint 1 and 2.
# * made it in a more interesting interconnected format than just learning from more lessons like sprint 2.
# * A highlight for this sprint was N@TM, where we could show off a cummulative product of all the work we had been doing for the past weeks.

# %% [markdown]
# ## N@TM Reflection
# N@TM went a lot better than I thought! I was able to see some of my friends who I haven't talked about compsci with and show off our project. I was also able to see the projects of my friends taking CSA, and that was super cool.
#
# #### Memorable Comments:
# * Avantika's Dad told me after I finished explaining that I was using a more advanced vocabulary than he thought this level would have, and that felt good because it felt like I really understood the material.
# * My friend I brought along with me said I looked more confident when explaining than I usually do.
#
# ![natm1](images/final/natm1.jpg)
# ![natm2](images/final/natm2.jpg)

# %% [markdown]
# ## What Next?
# With the addition of microblogs into our site, I like the idea of social media! For our next project, I'd like to lean into the social media aspect a little further and make what could be a fully fledged social media site. I feel like with social media, it could also show how these skills we learn in class translate into real world applications, with such a popular thing like social media. It could also give an insight into things like what a computer science position looks like for somebody who works for one of these social media sites.
#
# With this, I'd like to learn in the future skills that went along with this, things like running frontend and backend, dealing with data science and data structures, as well as databases for storage. Also, because our group briefly dived into CRUD procedures, I'd like to maybe do more with that in the future and actually apply it to databases in the future. Also, learning how we can turn concepts as broad as databases and CRUD procedures and how we're able to use it in real world applications.

# %% [markdown]
# ## MCQ Overview: Approach, Wrong Answers, and What I Learned
# ![score](images/final/score.png)
# #### Approach:
# I approached this in a way I would other quizzes and tests. I would try and narrow my options by crossing out answers I knew couldn't be true, then would try and find the best option out of what was left.
# After I finished taking the test, I went back over and reviewed the questions I missed, why I missed them, and what I can improve on so I don't miss them next time.
# #### Missed Questions
# ![score](images/final/question_3.png)
# * didn't have a firm understanding on what citizen science is. it's better to conduct science using multiple different locations so that you get a diverse sample size.
#
# ![score](images/final/question_12.png)
# * read the question wrong and assumed it was year 11 and not year 12.
#
# ![score](images/final/question_14.png)
# * didn't understand that it was the NUMBER of values, not the values themselves.
#
# ![score](images/final/question_21.png)
# * stupid mitstake. confused left from right/didn't read the right turn one that clearly.
#
# ![score](images/final/question_41.png)
# * only adds one score to the total, misinterpreted the code. the right answer adds the highest score and the final score.
#
# ![score](images/final/question_44.png)
# * I isn't big enough, II is larger than I which would result in an overflow error.
# * overflow error: a condition in computing that occurs when a program or system attempts to store or handle a value that is too large for the available data type or memory location.
#
# ![score](images/final/question_49.png)
# * loop shouldve iterated 4 times, not 16 times as shown in the answer i put.
#
# ![score](images/final/question_55.png)
# * thought it said OR instead of AND, because even if you hit y it won't display true because you didn't input yes.
#
# ![score](images/final/question_57.png)
# * the one i chose displays huppy, shouldve been 1-2, then 3-5.
#
# ![score](images/final/question_60.png)
# * C is not something that can be replaced easily, while the variables would be easier to replace.
#
# ![score](images/final/question_61.png)
# * east high school doesn't have id  so it can't track the students who has the highest absences. but they can calculate B because they have days and absences.
#
# ![score](images/final/question_65.png)
# * when x and y are both positive it will work correctly because y needs to be positive for it to work.
#
# ![score](images/final/question_66.png)
# * the one i chose still displays the smallest value, while C instead displays 40, the highest value.
